# %%
#!/usr/bin/env python
# -*- encoding: utf-8
import os
import itertools as itools
from dask.distributed import Client, LocalCluster
import core_scripts
from core_scripts import *

# %%
models = ["IPSL-CM6A-LR"]#["NorESM2-MM"]#
no_members = 4

members = [f"r{r}i1p1f1" for r in range(1, no_members+1)]
# members = ["r1i1p1f1", "r2i1p1f1", "r3i1p1f1"]
experiments = ["historical", "ssp370"]	
# combinations = [
#     f"--{model} --{member} --{experiment}"
#     for model, member, experiment
#         in itools.product(models, members, experiments)]
combinations = [
    dict(zip(["model", "experiment", "member"],[model, experiment, member]))
    for model, experiment, member
        in itools.product(models, experiments, members)]
combinations
# Out:
# [{'model': 'IPSL-CM6A-LR', 'experiment': 'historical', 'member': 'r1i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'historical', 'member': 'r2i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'historical', 'member': 'r3i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'historical', 'member': 'r4i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'ssp370', 'member': 'r1i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'ssp370', 'member': 'r2i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'ssp370', 'member': 'r3i1p1f1'},
#  {'model': 'IPSL-CM6A-LR', 'experiment': 'ssp370', 'member': 'r4i1p1f1'}]

# %%
cluster = LocalCluster(n_workers=10, memory_limit='8GiB')
client = Client(cluster)
print('Access dask dashboard: ', client.dashboard_link)
# Out:
# Access dask dashboard:  http://127.0.0.1:8787/status

# %%
print(combinations[1])
retrieve_data.main(**combinations[1], server="vesg.ipsl.upmc.fr") # Currently, the strucutre of retrieve_data.py is cumbersome and inflexible to Jupyter
# Out:
# {'model': 'IPSL-CM6A-LR', 'experiment': 'historical', 'member': 'r2i1p1f1'}
# IPSL-CM6A-LR historical r2i1p1f1 vesg.ipsl.upmc.fr
# Retrieving variable'ua'
# Servers available on https://esgf-data.dkrz.de/esg-search are:
#      vesg.ipsl.upmc.fr
#      esgf3.dkrz.de
# ['http://vesg.ipsl.upmc.fr/thredds/dodsC/cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r2i1p1f1/day/ua/gr/v20180803/ua_day_IPSL-CM6A-LR_historical_r2i1p1f1_gr_18500101-19491231.nc', 'http://vesg.ipsl.upmc.fr/thredds/dodsC/cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r2i1p1f1/day/ua/gr/v20180803/ua_day_IPSL-CM6A-LR_historical_r2i1p1f1_gr_19500101-20141231.nc']
# HDF5-DIAG: Error detected in HDF5 (1.14.6) thread 1:
#   #000: H5F.c line 496 in H5Fis_accessible(): unable to determine if file is accessible as HDF5
#     major: File accessibility
#     minor: Not an HDF5 file
#   #001: H5VLcallback.c line 3913 in H5VL_file_specific(): file specific failed
#     major: Virtual Object Layer
#     minor: Can't operate on object
# ...

# %%
model, experiment, member = combinations[2].values()
model, experiment, member
# Out:
# ('NorESM2-MM', 'historical', 'r3i1p1f1')

# %%
retrieve_data.retrieve_data_single_variable(
    model=model, experiment=experiment, member_id=member, variable='ua',
    plev=85000, select_plev=True, server='esgf.ceda.ac.uk') # 'esgf.ceda.ac.uk' # 'noresg.nird.sigma2.no' # 'esgf3.dkrz.de'#
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 retrieve_data.retrieve_data_single_variable(
#       2     model=model, experiment=experiment, member_id=member, variable='ua',
#       3     plev=85000, select_plev=True, server='esgf.ceda.ac.uk') # 'esgf.ceda.ac.uk' # 'noresg.nird.sigma2.no' # 'esgf3.dkrz.de'#
#
# File /shared_netapp1/share/ModData/CMIP_EU_Precip_Precursors/Johannes/CMIP-EU-precip-precursors/core_scripts/retrieve_data.py:62, in retrieve_data_single_variable(model, experiment, member_id, variable, select_plev, plev, **path_kwargs)
#      61 def retrieve_data_single_variable(model, experiment, member_id, variable, select_plev, plev=85000,**path_kwargs):
# ---> 62     path = cmip.esgf.get_path_CMIP6_data(model, experiment, member_id, variable, freq='day',table='day',**path_kwargs)
#      63     print(path)
# ...

# %%
cluster.close()
